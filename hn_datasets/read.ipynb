# %%
import pandas as pd

# %%
data = pd.read_csv("hacker_news_stories.csv")
data
# Out:
#                 by  descendants    id  \
# 0               pg           15     1
# 1          phyllis            0     2
# 2          phyllis            0     3
# 3      onebeerdave            0     4
# 4           perler            0     5
# ...            ...          ...   ...
# 2781       BitGeek            3  9969
# 2782         JMiao            2  9968
# 2783        farmer            1  9976
# 2784  theoutlander           27  9986
# 2785          danw            0  9996
#
#                                                    kids  score        time  \
# 0                           [15, 234509, 487171, 82729]     57  1160418111
# 1                                                   NaN     16  1160418628
# 2                                              [531602]      7  1160419233
# 3                                                   NaN      5  1160419662
# 4                                                   NaN      7  1160419864
# ...
